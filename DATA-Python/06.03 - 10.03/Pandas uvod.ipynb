# %% [markdown]
# # Pandas - Python Data Analysis Library

# %% [markdown]
# Znamo da Python ima nekoliko tipova podataka koji se odnose na kolekcije. To su liste, rječnici, n-terci. Rad s ovim tipovima podataka nije tako brz kao u jezicima baziranim na C-u ili u Fortranu. Zbog toga su nastale biblioteke koje imaju učinkovitost kao da su pisane u C-u ili Fortranu, a istovremeno imaju jednostavnost pisanja kôda kao u Pythonu.
#
# Pandas je jedna od njih. To je Python biblioteka za analizu i manipulaciju podataka, strukturiranih u obliku  tablice. Pandas koristi NumPy biblioteku kao podlogu. Njegova osnovna karakteristika je također rad s tabličnim tipom podataka koji može pohraniti samo podatke koji se zbrajaju i množe (najčešće brojeve). Pandas, s druge strane, također radi s tabličnim tipom podataka, ali za razliku od NumPy biblioteke, nema uvjet koji se tip podatka može pohraniti u tablici.

# %% [markdown]
# Pandas je jako korisna biblioteka i ovo su samo neke od situacija u kojima se koristi:<br>
# - upravljanje podacima koji nedostaju u tablicama s brojevima (na njihova mjesta dodaje *NaN - Not a Number*)
# - mogućnost promjene veličine objekta tako što se dodaju ili oduzimaju kolone iz *DataFrame* objekta
# - fleksibilno, a opet učinkovito grupiranje podataka koje omogućava modifikacije kao što su podjela, dodavanje, kombiniranje...
# - jednostavna konverzija Python i NumPy struktura podataka, bez obzira na način indeksacije izvornih objekata u *DateFrame* objekt
# - mogućnost izdvajanja dijelova podataka u zasebne cjeline na osnovi naziva kolona
# - promjena oblika i rotacija (eng. *pivoting*) tablica
# - uvoz i izvoz podataka iz datoteka CSV, Excel, baze podataka.
#
# ... i još puno drugih.

# %%
# pip install pandas

import pandas as pd

# %% [markdown]
# # Pandas struktura podataka

# %% [markdown]
# Pandas se koristi za rad s podacima u obliku tablice. Nudi mogućnost da se učita cijela tablica i od nje napravi Python objekt s kojim možemo raditi svakojake manipulacije na podacima unutar tog objekta.

# %% [markdown]
# ## Dataframe
#
# Tablični oblik pohrane podataka zastupljen je u bazama podataka, tabličnim kalkulatorima (Excel, CSV). Ovakav, tablični tip podataka u Pandasu naziva se ***DataFrame*** i on predstavlja tablicu koja ima više redaka i stupaca. *DataFrame* ima retke i stupce pa kažemo da ima dvije dimenzije (os 0 - stupci i os 1 - redovi).
#
# <img src="slike/01_table_dataframe.svg" alt="pandas dataframe"/>

# %%
data = {
    "Stupac 1": ["S1_Podatak 1", "S1_Podatak 2", "S1_Podatak 3", "S1_Podatak 4", "S1_Podatak 5"],
    "Stupac 2": ["S2_Podatak 1", "S2_Podatak 2", "S2_Podatak 3", "S2_Podatak 4", "S2_Podatak 5"],
    "Stupac 3": ["S3_Podatak 1", "S3_Podatak 2", "S3_Podatak 3", "S3_Podatak 4", "S3_Podatak 5"],
    "Stupac 4": ["S4_Podatak 1", "S4_Podatak 2", "S4_Podatak 3", "S4_Podatak 4", "S4_Podatak 5"],
}

# %%
df = pd.DataFrame(data)

df
# Out:
#        Stupac 1      Stupac 2      Stupac 3      Stupac 4
# 0  S1_Podatak 1  S2_Podatak 1  S3_Podatak 1  S4_Podatak 1
# 1  S1_Podatak 2  S2_Podatak 2  S3_Podatak 2  S4_Podatak 2
# 2  S1_Podatak 3  S2_Podatak 3  S3_Podatak 3  S4_Podatak 3
# 3  S1_Podatak 4  S2_Podatak 4  S3_Podatak 4  S4_Podatak 4
# 4  S1_Podatak 5  S2_Podatak 5  S3_Podatak 5  S4_Podatak 5

# %% [markdown]
# ## Pandas `series` ili serija
#
# Drugi oblik podataka, za čiju obradu se koristi Pandas je *Series* ili serija kako ćemo je mi zvati. Serija predstavlja stupac u *DataFrame* tablici i zbog toga ima samo jednu dimenziju (os 0).
#
# <img src="slike/01_table_series.svg" alt="pandas dataframe"/>

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Pristup podacima iz `dataframe-a`

# %%
df
# Out:
#        Stupac 1      Stupac 2      Stupac 3      Stupac 4
# 0  S1_Podatak 1  S2_Podatak 1  S3_Podatak 1  S4_Podatak 1
# 1  S1_Podatak 2  S2_Podatak 2  S3_Podatak 2  S4_Podatak 2
# 2  S1_Podatak 3  S2_Podatak 3  S3_Podatak 3  S4_Podatak 3
# 3  S1_Podatak 4  S2_Podatak 4  S3_Podatak 4  S4_Podatak 4
# 4  S1_Podatak 5  S2_Podatak 5  S3_Podatak 5  S4_Podatak 5

# %%
stupac = df["Stupac 1"]
stupac
# print(type(df["Stupac 1"]))
# Out:
# 0    S1_Podatak 1
# 1    S1_Podatak 2
# 2    S1_Podatak 3
# 3    S1_Podatak 4
# 4    S1_Podatak 5
# Name: Stupac 1, dtype: object

# %%
stupac.name
# Out:
# 'Stupac 1'

# %%
serija = pd.Series([5, 8, 2, 6, 5, 4, 8], name="Testna serija")
serija
# Out:
# 0    5
# 1    8
# 2    2
# 3    6
# 4    5
# 5    4
# 6    8
# Name: Testna serija, dtype: int64

# %%
serija_indeksi = pd.Series([5, 8, 2, 6], name="Indeks serija", index=["prvi", "drugi", "treci", "cetvrti"])
serija_indeksi
# Out:
# prvi       5
# drugi      8
# treci      2
# cetvrti    6
# Name: Indeks serija, dtype: int64

# %%
serija_indeksi["prvi"]
# Out:
# 5

# %%
serija_indeksi[1]
# Out:
# 8

# %%
serija_indeksi[::2]
# Out:
# prvi     5
# treci    2
# Name: Indeks serija, dtype: int64

# %%
serija_indeksi
# Out:
# prvi       5
# drugi      8
# treci      2
# cetvrti    6
# Name: Indeks serija, dtype: int64

# %%
serija_umnozak = serija_indeksi * 2

# %%
serija_umnozak
# Out:
# prvi       10
# drugi      16
# treci       4
# cetvrti    12
# Name: Indeks serija, dtype: int64

# %%
serija_indeksi
# Out:
# prvi       5
# drugi      8
# treci      2
# cetvrti    6
# Name: Indeks serija, dtype: int64

# %%
serija_indeksi["prvi"] = 7

# %%
serija_indeksi
# Out:
# prvi       7
# drugi      8
# treci      2
# cetvrti    6
# Name: Indeks serija, dtype: int64

# %%
serija_veci_od_6 = serija_indeksi[serija_indeksi > 6]

# %%
serija_indeksi > 6
# Out:
# prvi        True
# drugi       True
# treci      False
# cetvrti    False
# Name: Indeks serija, dtype: bool

# %%
serija_veci_od_6
# Out:
# prvi     7
# drugi    8
# Name: Indeks serija, dtype: int64

# %%
serija_duza = pd.Series([5, 6, 1, 7, 8, 2, 3, 1, 6, 7, 1, 5, 1, 6], name="Duza serija")
serija_duza
# Out:
# 0     5
# 1     6
# 2     1
# 3     7
# 4     8
# 5     2
# 6     3
# 7     1
# 8     6
# 9     7
# 10    1
# 11    5
# 12    1
# 13    6
# Name: Duza serija, dtype: int64

# %%
serija_duza.unique()  # jedinstveni elementi (bez ponavljanja)
# Out:
# array([5, 6, 1, 7, 8, 2, 3], dtype=int64)

# %%
print(type(serija_duza.unique()))
# Out:
# <class 'numpy.ndarray'>

# %%
# prebrojiti vrijednosti u seriji
serija_duza.value_counts().sort_values(ascending=False)
# Out:
# 1    4
# 6    3
# 5    2
# 7    2
# 8    1
# 2    1
# 3    1
# Name: Duza serija, dtype: int64

# %%
serija_duza.isin([1, 5, 7])
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13    False
# Name: Duza serija, dtype: bool

# %%
serija_duza[serija_duza.isin([1, 5, 7])]
# Out:
# 0     5
# 2     1
# 3     7
# 7     1
# 9     7
# 10    1
# 11    5
# 12    1
# Name: Duza serija, dtype: int64

# %% [markdown]
# ## Zadatak
#
# Generirajte nasumičnih 100 brojeva te ih pohranite u Python listu. Od te liste kreirajte Pandas seriju te joj dajte nekakav naziv.
#
# - Provjerite, koliko ima brojeva koji se ponavljaju te koliko se puta svaki od njih ponavlja?
# - Koji je broj najveći, a koji najmanji?
# - Modificirajte podatke u seriji tako da se svedu na postotke (neka budu u rasponu od 0 do 1).
# - Promijenite vrijednosti najvećeg broja tako da je identična vrijednosti najmanjeg broja. Provjerite koji je sada najveći broj.

# %%
import random as rd
lista = []

for i in range(100):
    lista.append(rd.randint(1, 101))

random_serija = pd.Series(lista, name="Random serija")

# %%
random_serija
# Out:
# 0     69
# 1     45
# 2     47
# 3     55
# 4     81
#       ..
# 95    18
# 96    44
# 97    67
# 98    58
# 99    90
# Name: Random serija, Length: 100, dtype: int64

# %%
random_serija.value_counts().sort_values(ascending=False)
# Out:
# 57    5
# 96    4
# 40    3
# 36    3
# 3     3
#      ..
# 46    1
# 21    1
# 42    1
# 33    1
# 53    1
# Name: Random serija, Length: 63, dtype: int64

# %%
random_serija.min()  # najmanja vrijednost u seriji
# Out:
# 1

# %%
random_serija.max()  # najveća vrijednost u seriji
# Out:
# 99

# %%
random_serija = random_serija / 100

# %%
random_serija
# Out:
# 0     0.67
# 1     0.40
# 2     0.52
# 3     0.74
# 4     0.70
#       ...
# 95    0.16
# 96    0.57
# 97    0.85
# 98    0.47
# 99    0.53
# Name: Random serija, Length: 100, dtype: float64

# %% [markdown]
# ### Zadatak
# **Tekst za obradu:**
#
# *Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.*
#
# Obradite gore navedeni tekst tako da od njega kreirate listu riječi koje imaju sva mala slova i nemaju znakove interpunkcije. Od te liste kreirajte Pandas seriju te joj dajte nekakav naziv.
#
# Provjerite, koliko ima riječi koje se ponavljaju te koliko puta se svaka od njih ponavlja?
# Provjerite koja je najduža, a koja najkraća riječ.

# %%
paragraf = "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."

paragraf = paragraf.lower().replace(".", "").replace(",", "")
print(paragraf)
# Out:
# lorem ipsum dolor sit amet consectetur adipiscing elit sed do eiusmod tempor incididunt ut labore et dolore magna aliqua ut enim ad minim veniam quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur excepteur sint occaecat cupidatat non proident sunt in culpa qui officia deserunt mollit anim id est laborum

# %%
lista_rijeci = paragraf.split()  # .split(" ")
print(lista_rijeci)
# Out:
# ['lorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur', 'adipiscing', 'elit', 'sed', 'do', 'eiusmod', 'tempor', 'incididunt', 'ut', 'labore', 'et', 'dolore', 'magna', 'aliqua', 'ut', 'enim', 'ad', 'minim', 'veniam', 'quis', 'nostrud', 'exercitation', 'ullamco', 'laboris', 'nisi', 'ut', 'aliquip', 'ex', 'ea', 'commodo', 'consequat', 'duis', 'aute', 'irure', 'dolor', 'in', 'reprehenderit', 'in', 'voluptate', 'velit', 'esse', 'cillum', 'dolore', 'eu', 'fugiat', 'nulla', 'pariatur', 'excepteur', 'sint', 'occaecat', 'cupidatat', 'non', 'proident', 'sunt', 'in', 'culpa', 'qui', 'officia', 'deserunt', 'mollit', 'anim', 'id', 'est', 'laborum']

# %%
pd_rijeci = pd.Series(lista_rijeci, name="Lorem ipsum")

# %%
pd_rijeci
# Out:
# 0       lorem
# 1       ipsum
# 2       dolor
# 3         sit
# 4        amet
#        ...
# 64     mollit
# 65       anim
# 66         id
# 67        est
# 68    laborum
# Name: Lorem ipsum, Length: 69, dtype: object

# %%
pd_rijeci.value_counts().sort_values(ascending=False)
# Out:
# in          3
# ut          3
# dolore      2
# dolor       2
# elit        1
#            ..
# officia     1
# deserunt    1
# mollit      1
# anim        1
# laborum     1
# Name: Lorem ipsum, Length: 63, dtype: int64

# %%
broj_ponavljanja = pd_rijeci.value_counts()

# %%
broj_ponavljanja[broj_ponavljanja > 1]
# Out:
# in        3
# ut        3
# dolore    2
# dolor     2
# Name: Lorem ipsum, dtype: int64

# %%
pd_rijeci
# Out:
# 0       lorem
# 1       ipsum
# 2       dolor
# 3         sit
# 4        amet
#        ...
# 64     mollit
# 65       anim
# 66         id
# 67        est
# 68    laborum
# Name: Lorem ipsum, Length: 69, dtype: object

# %%
pd_rijeci.min()  # najkraća riječ
# Out:
# 'ad'

# %% [markdown]
# pd_rijeci.max()  # najduža riječ

# %% [markdown]
# ## Dataframe

# %%
proizvodi_baza = {
    "Naziv": [
        "Trek", "Kona", "Giant",
        "Bianchi", "Cosmo Ride", "Neon",
        "Zeeclo", "Atomic", "Head",
        "Elan", "Salomon", "Rossignol"
    ],
    "Cijena": [
        7699.00, 4699.00, 5999.00,
        22499.00, 2599.00, 1999.00,
        2799.00, 1499.00, 1359.00,
        1499.00, 1699.00, 999.00
    ],
    "Kategorija": [
        "Bicikl", "Bicikl", "Bicikl",
        "Bicikl", "E-Romobil", "E-Romobil",
        "E-Romobil", "Skije", "Skije",
        "Skije", "Skije", "Skije"
    ],
    "Ocjena": [
        6.7, 6.5, 6.65,
        7.2, 8.64, 8.61,
        8.59, 7.99, 8.15,
        8.05, 7.91, 6.10
    ]
}

# %%
proizvodi = pd.DataFrame(proizvodi_baza)
proizvodi
# Out:
#          Naziv   Cijena Kategorija  Ocjena
# 0         Trek   7699.0     Bicikl    6.70
# 1         Kona   4699.0     Bicikl    6.50
# 2        Giant   5999.0     Bicikl    6.65
# 3      Bianchi  22499.0     Bicikl    7.20
# 4   Cosmo Ride   2599.0  E-Romobil    8.64
# 5         Neon   1999.0  E-Romobil    8.61
# 6       Zeeclo   2799.0  E-Romobil    8.59
# 7       Atomic   1499.0      Skije    7.99
# 8         Head   1359.0      Skije    8.15
# 9         Elan   1499.0      Skije    8.05
# 10     Salomon   1699.0      Skije    7.91
# 11   Rossignol    999.0      Skije    6.10

# %%
proizvodi_dio = pd.DataFrame(proizvodi_baza, columns=["Naziv", "Cijena"])
proizvodi_dio
# Out:
#          Naziv   Cijena
# 0         Trek   7699.0
# 1         Kona   4699.0
# 2        Giant   5999.0
# 3      Bianchi  22499.0
# 4   Cosmo Ride   2599.0
# 5         Neon   1999.0
# 6       Zeeclo   2799.0
# 7       Atomic   1499.0
# 8         Head   1359.0
# 9         Elan   1499.0
# 10     Salomon   1699.0
# 11   Rossignol    999.0

# %% [markdown]
# Dataframe najčešće nećemo kreirati na ovaj način, već ćemo ga dobiti učitavanjem podataka iz nekog izvora, primjerice `.csv` datoteke. U tom slučaju, jedan od prvih koraka prije bilo kakve analize tih podataka je vidjeti s kojim podacima raspolažemo:

# %%
proizvodi.columns
# Out:
# Index(['Naziv', 'Cijena', 'Kategorija', 'Ocjena'], dtype='object')

# %%
proizvodi.values
# Out:
# array([['Trek', 7699.0, 'Bicikl', 6.7],
#        ['Kona', 4699.0, 'Bicikl', 6.5],
#        ['Giant', 5999.0, 'Bicikl', 6.65],
#        ['Bianchi', 22499.0, 'Bicikl', 7.2],
#        ['Cosmo Ride', 2599.0, 'E-Romobil', 8.64],
#        ['Neon', 1999.0, 'E-Romobil', 8.61],
#        ['Zeeclo', 2799.0, 'E-Romobil', 8.59],
#        ['Atomic', 1499.0, 'Skije', 7.99],
#        ['Head', 1359.0, 'Skije', 8.15],
#        ['Elan', 1499.0, 'Skije', 8.05],
#        ['Salomon', 1699.0, 'Skije', 7.91],
#        ['Rossignol', 999.0, 'Skije', 6.1]], dtype=object)

# %%
proizvodi.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
proizvodi.index.name = "ID"

# %%
proizvodi
# Out:
#          Naziv   Cijena Kategorija  Ocjena
# ID
# 0         Trek   7699.0     Bicikl    6.70
# 1         Kona   4699.0     Bicikl    6.50
# 2        Giant   5999.0     Bicikl    6.65
# 3      Bianchi  22499.0     Bicikl    7.20
# 4   Cosmo Ride   2599.0  E-Romobil    8.64
# 5         Neon   1999.0  E-Romobil    8.61
# 6       Zeeclo   2799.0  E-Romobil    8.59
# 7       Atomic   1499.0      Skije    7.99
# 8         Head   1359.0      Skije    8.15
# 9         Elan   1499.0      Skije    8.05
# 10     Salomon   1699.0      Skije    7.91
# 11   Rossignol    999.0      Skije    6.10

# %% [markdown]
# ### Pristup elementima u `dataframe-u`

# %%
# pristup stupcu

proizvodi["Naziv"]
# Out:
# ID
# 0           Trek
# 1           Kona
# 2          Giant
# 3        Bianchi
# 4     Cosmo Ride
# 5           Neon
# 6         Zeeclo
# 7         Atomic
# 8           Head
# 9           Elan
# 10       Salomon
# 11     Rossignol
# Name: Naziv, dtype: object

# %%
# pristup retku
proizvodi[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\programdata\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\programdata\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\programdata\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 # pristup retku
# ----> 2 proizvodi[0]
#
# File c:\programdata\miniconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\programdata\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# Očito retku ne pristupamo na ovaj način.

# %%
proizvodi["Naziv"][11]
# Out:
# 'Rossignol'

# %%
proizvodi["Naziv"][:5:-1]
# Out:
# ID
# 11    Rossignol
# 10      Salomon
# 9          Elan
# 8          Head
# 7        Atomic
# 6        Zeeclo
# Name: Naziv, dtype: object

# %%
proizvodi[:1]
# Out:
#    Naziv  Cijena Kategorija  Ocjena
# ID
# 0   Trek  7699.0     Bicikl     6.7

# %%
proizvodi.loc[0]  # dohvat prvog retka u dataframe-u, rezultat je serija
# Out:
# Naziv           Trek
# Cijena        7699.0
# Kategorija    Bicikl
# Ocjena           6.7
# Name: 0, dtype: object

# %%
proizvodi.loc[[0, 2, 7]]  # dohvat više proizvoljnih redaka iz dataframe-e, rezultat je drugi dataframe
# Out:
#      Naziv  Cijena Kategorija  Ocjena
# ID
# 0     Trek  7699.0     Bicikl    6.70
# 2    Giant  5999.0     Bicikl    6.65
# 7   Atomic  1499.0      Skije    7.99

# %%
# dodavanje novog stupca u dataframeu

# %%
proizvodi["Količina na skladištu"] = 15
proizvodi
# Out:
#          Naziv   Cijena Kategorija  Ocjena  Količina na skladištu
# ID
# 0         Trek   7699.0     Bicikl    6.70                     15
# 1         Kona   4699.0     Bicikl    6.50                     15
# 2        Giant   5999.0     Bicikl    6.65                     15
# 3      Bianchi  22499.0     Bicikl    7.20                     15
# 4   Cosmo Ride   2599.0  E-Romobil    8.64                     15
# 5         Neon   1999.0  E-Romobil    8.61                     15
# 6       Zeeclo   2799.0  E-Romobil    8.59                     15
# 7       Atomic   1499.0      Skije    7.99                     15
# 8         Head   1359.0      Skije    8.15                     15
# 9         Elan   1499.0      Skije    8.05                     15
# 10     Salomon   1699.0      Skije    7.91                     15
# 11   Rossignol    999.0      Skije    6.10                     15

# %%
import numpy as np

proizvodi["Količina na skladištu"] = np.random.randint(100, size=12)
proizvodi
# Out:
#          Naziv   Cijena Kategorija  Ocjena  Količina na skladištu
# ID
# 0         Trek   7699.0     Bicikl    6.70                     28
# 1         Kona   4699.0     Bicikl    6.50                     53
# 2        Giant   5999.0     Bicikl    6.65                     21
# 3      Bianchi  22499.0     Bicikl    7.20                     47
# 4   Cosmo Ride   2599.0  E-Romobil    8.64                     45
# 5         Neon   1999.0  E-Romobil    8.61                     99
# 6       Zeeclo   2799.0  E-Romobil    8.59                     13
# 7       Atomic   1499.0      Skije    7.99                     17
# 8         Head   1359.0      Skije    8.15                      2
# 9         Elan   1499.0      Skije    8.05                     37
# 10     Salomon   1699.0      Skije    7.91                     47
# 11   Rossignol    999.0      Skije    6.10                     73

# %%
# brisanje stupca iz dataframe-a
del proizvodi["Količina na skladištu"]
proizvodi
# Out:
#          Naziv   Cijena Kategorija  Ocjena
# ID
# 0         Trek   7699.0     Bicikl    6.70
# 1         Kona   4699.0     Bicikl    6.50
# 2        Giant   5999.0     Bicikl    6.65
# 3      Bianchi  22499.0     Bicikl    7.20
# 4   Cosmo Ride   2599.0  E-Romobil    8.64
# 5         Neon   1999.0  E-Romobil    8.61
# 6       Zeeclo   2799.0  E-Romobil    8.59
# 7       Atomic   1499.0      Skije    7.99
# 8         Head   1359.0      Skije    8.15
# 9         Elan   1499.0      Skije    8.05
# 10     Salomon   1699.0      Skije    7.91
# 11   Rossignol    999.0      Skije    6.10

# %% [markdown]
# # Čitanje i pisanje podataka

# %%
cars = pd.read_csv("podaci/cars.csv")
cars
# Out:
#     Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0    STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1    Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2    Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3    Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4    AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US
# ..                                                 ...
# 402  Ford Mustang GL;27.0;4;140.0;86.00;2790.;15.6;...
# 403  Volkswagen Pickup;44.0;4;97.00;52.00;2130.;24....
# 404  Dodge Rampage;32.0;4;135.0;84.00;2295.;11.6;82;US
# 405    Ford Ranger;28.0;4;120.0;79.00;2625.;18.6;82;US
# 406     Chevy S-10;31.0;4;119.0;82.00;2720.;19.4;82;US
#
# [407 rows x 1 columns]

# %% [markdown]
# Ovo baš nije najsretniji format iz kojeg možemo nešto zaključiti jer nam se sve nalazi u jednom stupcu. Zašto? Zato što su podaci u našem `.csv-u` odvojeni sa `;`, dok `pandas` kao defaultni separator očekuje `,`.
#
# To je problem koji možemo vrlo jednostavno riješiti.

# %%
cars = pd.read_csv("podaci/cars.csv", sep=";")
cars
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# 1     3504.         12.0    70      US
# 2     3693.         11.5    70      US
# 3     3436.         11.0    70      US
# 4     3433.         12.0    70      US
# ..      ...          ...   ...     ...
# 402   2790.         15.6    82      US
# 403   2130.         24.6    82  Europe
# 404   2295.         11.6    82      US
# 405   2625.         18.6    82      US
# 406   2720.         19.4    82      US
#
# [407 rows x 9 columns]

# %%
cars.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
cars.values
# Out:
# array([['STRING', 'DOUBLE', 'INT', ..., 'DOUBLE', 'INT', 'CAT'],
#        ['Chevrolet Chevelle Malibu', '18.0', '8', ..., '12.0', '70',
#         'US'],
#        ['Buick Skylark 320', '15.0', '8', ..., '11.5', '70', 'US'],
#        ...,
#        ['Dodge Rampage', '32.0', '4', ..., '11.6', '82', 'US'],
#        ['Ford Ranger', '28.0', '4', ..., '18.6', '82', 'US'],
#        ['Chevy S-10', '31.0', '4', ..., '19.4', '82', 'US']], dtype=object)

# %%
cars.dtypes
# Out:
# Car             object
# MPG             object
# Cylinders       object
# Displacement    object
# Horsepower      object
# Weight          object
# Acceleration    object
# Model           object
# Origin          object
# dtype: object

# %%
cars = cars.drop(0)  
cars["Horsepower"] = cars["Horsepower"].astype("float")
# Out:
#                            Car   MPG Cylinders Displacement  Horsepower  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0       130.0
# 2            Buick Skylark 320  15.0         8        350.0       165.0
# 3           Plymouth Satellite  18.0         8        318.0       150.0
# 4                AMC Rebel SST  16.0         8        304.0       150.0
# 5                  Ford Torino  17.0         8        302.0       140.0
# ..                         ...   ...       ...          ...         ...
# 402            Ford Mustang GL  27.0         4        140.0        86.0
# 403          Volkswagen Pickup  44.0         4        97.00        52.0
# 404              Dodge Rampage  32.0         4        135.0        84.0
# 405                Ford Ranger  28.0         4        120.0        79.0
# 406                 Chevy S-10  31.0         4        119.0        82.0
#
#     Weight Acceleration Model  Origin
# 1    3504.         12.0    70      US
# 2    3693.         11.5    70      US
# 3    3436.         11.0    70      US
# 4    3433.         12.0    70      US
# 5    3449.         10.5    70      US
# ..     ...          ...   ...     ...
# 402  2790.         15.6    82      US
# 403  2130.         24.6    82  Europe
# 404  2295.         11.6    82      US
# 405  2625.         18.6    82      US
# 406  2720.         19.4    82      US
#
# [406 rows x 9 columns]

# %%
cars.dtypes
# Out:
# Car              object
# MPG              object
# Cylinders        object
# Displacement     object
# Horsepower      float64
# Weight           object
# Acceleration     object
# Model            object
# Origin           object
# dtype: object

# %%
cars["MPG"] = cars["MPG"].astype("float")
cars["Cylinders"] = cars["Cylinders"].astype("int")
cars["Displacement"] = cars["Displacement"].astype("float")
cars["Weight"] = cars["Weight"].astype(float)
cars["Acceleration"] = cars["Acceleration"].astype("float")
cars["Model"] = cars["Model"].astype("int")

cars.dtypes
# Out:
# Car              object
# MPG             float64
# Cylinders         int32
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model             int32
# Origin           object
# dtype: object

# %%
cars["Car"] = cars["Car"].astype("string")
cars.dtypes
# Out:
# Car              string
# MPG             float64
# Cylinders         int32
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model             int32
# Origin           object
# dtype: object

# %%
cars = pd.read_csv("podaci/cars.csv", sep=";", skiprows=[1])
cars
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1            Buick Skylark 320  15.0          8         350.0       165.0
# 2           Plymouth Satellite  18.0          8         318.0       150.0
# 3                AMC Rebel SST  16.0          8         304.0       150.0
# 4                  Ford Torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0          4         140.0        86.0
# 402          Volkswagen Pickup  44.0          4          97.0        52.0
# 403              Dodge Rampage  32.0          4         135.0        84.0
# 404                Ford Ranger  28.0          4         120.0        79.0
# 405                 Chevy S-10  31.0          4         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# 0    3504.0          12.0     70      US
# 1    3693.0          11.5     70      US
# 2    3436.0          11.0     70      US
# 3    3433.0          12.0     70      US
# 4    3449.0          10.5     70      US
# ..      ...           ...    ...     ...
# 401  2790.0          15.6     82      US
# 402  2130.0          24.6     82  Europe
# 403  2295.0          11.6     82      US
# 404  2625.0          18.6     82      US
# 405  2720.0          19.4     82      US
#
# [406 rows x 9 columns]

# %%
cars.dtypes
# Out:
# Car              object
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model             int64
# Origin           object
# dtype: object

# %%
cars.head(20)  # prvih 20 redaka u dataframe-u
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 0          Chevrolet Chevelle Malibu  18.0          8         307.0
# 1                  Buick Skylark 320  15.0          8         350.0
# 2                 Plymouth Satellite  18.0          8         318.0
# 3                      AMC Rebel SST  16.0          8         304.0
# 4                        Ford Torino  17.0          8         302.0
# 5                   Ford Galaxie 500  15.0          8         429.0
# 6                   Chevrolet Impala  14.0          8         454.0
# 7                  Plymouth Fury iii  14.0          8         440.0
# 8                   Pontiac Catalina  14.0          8         455.0
# 9                 AMC Ambassador DPL  15.0          8         390.0
# 10              Citroen DS-21 Pallas   0.0          4         133.0
# 11  Chevrolet Chevelle Concours (sw)   0.0          8         350.0
# 12                  Ford Torino (sw)   0.0          8         351.0
# 13           Plymouth Satellite (sw)   0.0          8         383.0
# 14                AMC Rebel SST (sw)   0.0          8         360.0
# 15               Dodge Challenger SE  15.0          8         383.0
# 16                Plymouth 'Cuda 340  14.0          8         340.0
# 17             Ford Mustang Boss 302   0.0          8         302.0
# 18             Chevrolet Monte Carlo  15.0          8         400.0
# 19           Buick Estate Wagon (sw)  14.0          8         455.0
#
#     Horsepower  Weight  Acceleration  Model  Origin
# 0        130.0  3504.0          12.0     70      US
# 1        165.0  3693.0          11.5     70      US
# 2        150.0  3436.0          11.0     70      US
# 3        150.0  3433.0          12.0     70      US
# 4        140.0  3449.0          10.5     70      US
# 5        198.0  4341.0          10.0     70      US
# 6        220.0  4354.0           9.0     70      US
# 7        215.0  4312.0           8.5     70      US
# 8        225.0  4425.0          10.0     70      US
# 9        190.0  3850.0           8.5     70      US
# 10       115.0  3090.0          17.5     70  Europe
# 11       165.0  4142.0          11.5     70      US
# 12       153.0  4034.0          11.0     70      US
# 13       175.0  4166.0          10.5     70      US
# 14       175.0  3850.0          11.0     70      US
# 15       170.0  3563.0          10.0     70      US
# 16       160.0  3609.0           8.0     70      US
# 17       140.0  3353.0           8.0     70      US
# 18       150.0  3761.0           9.5     70      US
# 19       225.0  3086.0          10.0     70      US

# %%
cars.tail(20)   # zadnjih 20 redaka u dataframeu
# Out:
#                                    Car   MPG  Cylinders  Displacement  \
# 386             Plymouth Horizon Miser  38.0          4         105.0
# 387                     Mercury Lynx l  36.0          4          98.0
# 388                   Nissan Stanza XE  36.0          4         120.0
# 389                       Honda Accord  36.0          4         107.0
# 390                     Toyota Corolla  34.0          4         108.0
# 391                        Honda Civic  38.0          4          91.0
# 392                 Honda Civic (auto)  32.0          4          91.0
# 393                      Datsun 310 GX  38.0          4          91.0
# 394              Buick Century Limited  25.0          6         181.0
# 395  Oldsmobile Cutlass Ciera (diesel)  38.0          6         262.0
# 396         Chrysler Lebaron Medallion  26.0          4         156.0
# 397                     Ford Grenada l  22.0          6         232.0
# 398                   Toyota Celica GT  32.0          4         144.0
# 399                  Dodge Charger 2.2  36.0          4         135.0
# 400                   Chevrolet Camaro  27.0          4         151.0
# 401                    Ford Mustang GL  27.0          4         140.0
# 402                  Volkswagen Pickup  44.0          4          97.0
# 403                      Dodge Rampage  32.0          4         135.0
# 404                        Ford Ranger  28.0          4         120.0
# 405                         Chevy S-10  31.0          4         119.0
#
#      Horsepower  Weight  Acceleration  Model  Origin
# 386        63.0  2125.0          14.7     82      US
# 387        70.0  2125.0          17.3     82      US
# 388        88.0  2160.0          14.5     82   Japan
# 389        75.0  2205.0          14.5     82   Japan
# 390        70.0  2245.0          16.9     82   Japan
# 391        67.0  1965.0          15.0     82   Japan
# 392        67.0  1965.0          15.7     82   Japan
# 393        67.0  1995.0          16.2     82   Japan
# 394       110.0  2945.0          16.4     82      US
# 395        85.0  3015.0          17.0     82      US
# 396        92.0  2585.0          14.5     82      US
# 397       112.0  2835.0          14.7     82      US
# 398        96.0  2665.0          13.9     82   Japan
# 399        84.0  2370.0          13.0     82      US
# 400        90.0  2950.0          17.3     82      US
# 401        86.0  2790.0          15.6     82      US
# 402        52.0  2130.0          24.6     82  Europe
# 403        84.0  2295.0          11.6     82      US
# 404        79.0  2625.0          18.6     82      US
# 405        82.0  2720.0          19.4     82      US

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 28.7+ KB

# %%
cars.empty   # provjera imamo li praznu "ćeliju" u našem dataframe-u
# Out:
# False

# %% [markdown]
# ## Zadatak

# %% [markdown]
# Učitati podatke iz datoteke `e-cars.csv` u `dataframe` i odraditi njihovu normalizaciju, tj čišćenje.

# %%
e_cars = pd.read_csv("podaci/e-cars.csv", sep=";")

e_cars
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 11  2014   CHEVROLET                         SPARK EV             SUBCOMPACT
# 12  2014        FORD                   FOCUS ELECTRIC                COMPACT
# 13  2014  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 14  2014      NISSAN                             LEAF               MID-SIZE
# 15  2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 16  2014       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 17  2014       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 18  2014       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 19  2014       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 20  2015         BMW                               i3             SUBCOMPACT
# 21  2015   CHEVROLET                         SPARK EV             SUBCOMPACT
# 22  2015        FORD                   FOCUS ELECTRIC                COMPACT
# 23  2015         KIA                          SOUL EV  STATION WAGON - SMALL
# 24  2015  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 25  2015      NISSAN                             LEAF               MID-SIZE
# 26  2015       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 27  2015       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 28  2015       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 29  2015       TESLA         MODEL S (70 kWh battery)              FULL-SIZE
# 30  2015       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 31  2015       TESLA                      MODEL S 70D              FULL-SIZE
# 32  2015       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 33  2015       TESLA                MODEL S P85D/P90D              FULL-SIZE
# 34  2016         BMW                               i3             SUBCOMPACT
# 35  2016   CHEVROLET                         SPARK EV             SUBCOMPACT
# 36  2016        FORD                   FOCUS ELECTRIC                COMPACT
# 37  2016         KIA                          SOUL EV  STATION WAGON - SMALL
# 38  2016  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 39  2016      NISSAN            LEAF (24 kWh battery)               MID-SIZE
# 40  2016      NISSAN            LEAF (30 kWh battery)               MID-SIZE
# 41  2016       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 42  2016       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 43  2016       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 44  2016       TESLA         MODEL S (70 kWh battery)              FULL-SIZE
# 45  2016       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 46  2016       TESLA                      MODEL S 70D              FULL-SIZE
# 47  2016       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 48  2016       TESLA            MODEL S 90D (Refresh)              FULL-SIZE
# 49  2016       TESLA                MODEL S P85D/P90D              FULL-SIZE
# 50  2016       TESLA           MODEL S P90D (Refresh)              FULL-SIZE
# 51  2016       TESLA                      MODEL X 90D         SUV - STANDARD
# 52  2016       TESLA                     MODEL X P90D         SUV - STANDARD
#
#     (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# 0     49         A1    B               16.9              21.4
# 1     80         A1    B               19.3              23.0
# 2    107         A1    B               19.0              21.1
# 3     49         A1    B               16.9              21.4
# 4     80         A1    B               19.3              23.0
# 5     35         A1    B               17.2              22.5
# 6     35         A1    B               17.2              22.5
# 7    270         A1    B               22.4              21.9
# 8    270         A1    B               22.2              21.7
# 9    270         A1    B               23.8              23.2
# 10   310         A1    B               23.9              23.2
# 11   104         A1    B               16.0              19.6
# 12   107         A1    B               19.0              21.1
# 13    49         A1    B               16.9              21.4
# 14    80         A1    B               16.5              20.8
# 15    35         A1    B               17.2              22.5
# 16    35         A1    B               17.2              22.5
# 17   225         A1    B               22.2              21.7
# 18   270         A1    B               23.8              23.2
# 19   310         A1    B               23.9              23.2
# 20   125         A1    B               15.2              18.8
# 21   104         A1    B               16.0              19.6
# 22   107         A1    B               19.0              21.1
# 23    81         A1    B               17.5              22.7
# 24    49         A1    B               16.9              21.4
# 25    80         A1    B               16.5              20.8
# 26    35         A1    B               17.2              22.5
# 27    35         A1    B               17.2              22.5
# 28   283         A1    B               22.2              21.7
# 29   283         A1    B               23.8              23.2
# 30   283         A1    B               23.8              23.2
# 31   280         A1    B               20.8              20.6
# 32   280         A1    B               22.0              19.8
# 33   515         A1    B               23.4              21.5
# 34   125         A1    B               15.2              18.8
# 35   104         A1    B               16.0              19.6
# 36   107         A1    B               19.0              21.1
# 37    81         A1    B               17.5              22.7
# 38    49         A1    B               16.9              21.4
# 39    80         A1    B               16.5              20.8
# 40    80         A1    B               17.0              20.7
# 41    35         A1    B               17.2              22.5
# 42    35         A1    B               17.2              22.5
# 43   283         A1    B               22.2              21.7
# 44   283         A1    B               23.8              23.2
# 45   283         A1    B               23.8              23.2
# 46   386         A1    B               20.8              20.6
# 47   386         A1    B               22.0              19.8
# 48   386         A1    B               20.8              19.7
# 49   568         A1    B               23.4              21.5
# 50   568         A1    B               22.9              21.0
# 51   386         A1    B               23.2              22.2
# 52   568         A1    B               23.6              23.3
#
#     COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  \
# 0                18.7               1.9              2.4               2.1
# 1                21.1               2.2              2.6               2.4
# 2                20.0               2.1              2.4               2.2
# 3                18.7               1.9              2.4               2.1
# 4                21.1               2.2              2.6               2.4
# 5                19.6               1.9              2.5               2.2
# 6                19.6               1.9              2.5               2.2
# 7                22.2               2.5              2.5               2.5
# 8                21.9               2.5              2.4               2.5
# 9                23.6               2.7              2.6               2.6
# 10               23.6               2.7              2.6               2.6
# 11               17.8               1.8              2.2               2.0
# 12               20.0               2.1              2.4               2.2
# 13               18.7               1.9              2.4               2.1
# 14               18.4               1.9              2.3               2.1
# 15               19.6               1.9              2.5               2.2
# 16               19.6               1.9              2.5               2.2
# 17               21.9               2.5              2.4               2.5
# 18               23.6               2.7              2.6               2.6
# 19               23.6               2.7              2.6               2.6
# 20               16.8               1.7              2.1               1.9
# 21               17.8               1.8              2.2               2.0
# 22               20.0               2.1              2.4               2.2
# 23               19.9               2.0              2.6               2.2
# 24               18.7               1.9              2.4               2.1
# 25               18.4               1.9              2.3               2.1
# 26               19.6               1.9              2.5               2.2
# 27               19.6               1.9              2.5               2.2
# 28               21.9               2.5              2.4               2.5
# 29               23.6               2.7              2.6               2.6
# 30               23.6               2.7              2.6               2.6
# 31               20.7               2.3              2.3               2.3
# 32               21.0               2.5              2.2               2.4
# 33               22.5               2.6              2.4               2.5
# 34               16.8               1.7              2.1               1.9
# 35               17.8               1.8              2.2               2.0
# 36               20.0               2.1              2.4               2.2
# 37               19.9               2.0              2.6               2.2
# 38               18.7               1.9              2.4               2.1
# 39               18.4               1.9              2.3               2.1
# 40               18.6               1.9              2.3               2.1
# 41               19.6               1.9              2.5               2.2
# 42               19.6               1.9              2.5               2.2
# 43               21.9               2.5              2.4               2.5
# 44               23.6               2.7              2.6               2.6
# 45               23.6               2.7              2.6               2.6
# 46               20.7               2.3              2.3               2.3
# 47               21.0               2.5              2.2               2.4
# 48               20.3               2.3              2.2               2.3
# 49               22.5               2.6              2.4               2.5
# 50               22.1               2.6              2.4               2.5
# 51               22.7               2.6              2.5               2.6
# 52               23.5               2.7              2.6               2.6
#
#     (g/km)  RATING  (km)  TIME (h)
# 0        0     NaN   100         7
# 1        0     NaN   117         7
# 2        0     NaN   122         4
# 3        0     NaN   100         7
# 4        0     NaN   117         7
# 5        0     NaN   109         8
# 6        0     NaN   109         8
# 7        0     NaN   224         6
# 8        0     NaN   335        10
# 9        0     NaN   426        12
# 10       0     NaN   426        12
# 11       0     NaN   131         7
# 12       0     NaN   122         4
# 13       0     NaN   100         7
# 14       0     NaN   135         5
# 15       0     NaN   109         8
# 16       0     NaN   109         8
# 17       0     NaN   335        10
# 18       0     NaN   426        12
# 19       0     NaN   426        12
# 20       0     NaN   130         4
# 21       0     NaN   131         7
# 22       0     NaN   122         4
# 23       0     NaN   149         4
# 24       0     NaN   100         7
# 25       0     NaN   135         5
# 26       0     NaN   109         8
# 27       0     NaN   109         8
# 28       0     NaN   335        10
# 29       0     NaN   377        12
# 30       0     NaN   426        12
# 31       0     NaN   386        12
# 32       0     NaN   435        12
# 33       0     NaN   407        12
# 34       0    10.0   130         4
# 35       0    10.0   131         7
# 36       0    10.0   122         4
# 37       0    10.0   149         4
# 38       0    10.0   100         7
# 39       0    10.0   135         5
# 40       0    10.0   172         6
# 41       0    10.0   109         8
# 42       0    10.0   109         8
# 43       0    10.0   335        10
# 44       0    10.0   377        12
# 45       0    10.0   426        12
# 46       0    10.0   386        12
# 47       0    10.0   435        12
# 48       0    10.0   473        12
# 49       0    10.0   407        12
# 50       0    10.0   435        12
# 51       0    10.0   414        12
# 52       0    10.0   402        12

# %%
e_cars.columns
# Out:
# Index(['YEAR', 'Make', 'Model', 'Size', '(kW)', 'Unnamed: 5', 'TYPE',
#        'CITY (kWh/100 km)', 'HWY (kWh/100 km)', 'COMB (kWh/100 km)',
#        'CITY (Le/100 km)', 'HWY (Le/100 km)', 'COMB (Le/100 km)', '(g/km)',
#        'RATING', '(km)', 'TIME (h)'],
#       dtype='object')

# %%
e_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               53 non-null     int64
#  1   Make               53 non-null     object
#  2   Model              53 non-null     object
#  3   Size               53 non-null     object
#  4   (kW)               53 non-null     int64
#  5   Unnamed: 5         53 non-null     object
#  6   TYPE               53 non-null     object
#  7   CITY (kWh/100 km)  53 non-null     float64
#  8   HWY (kWh/100 km)   53 non-null     float64
#  9   COMB (kWh/100 km)  53 non-null     float64
#  10  CITY (Le/100 km)   53 non-null     float64
#  11  HWY (Le/100 km)    53 non-null     float64
#  12  COMB (Le/100 km)   53 non-null     float64
#  13  (g/km)             53 non-null     int64
#  14  RATING             19 non-null     float64
#  15  (km)               53 non-null     int64
#  16  TIME (h)           53 non-null     int64
# dtypes: float64(7), int64(5), object(5)
# memory usage: 7.2+ KB

# %%
e_cars["Unnamed: 5"].unique()
# Out:
# array(['A1'], dtype=object)

# %%
e_cars["Unnamed: 5"].value_counts()
# Out:
# A1    53
# Name: Unnamed: 5, dtype: int64

# %%
e_cars["Make"].unique()
# Out:
# array(['MITSUBISHI', 'NISSAN', 'FORD', 'SMART', 'TESLA', 'CHEVROLET',
#        'BMW', 'KIA'], dtype=object)

# %%
e_cars["TYPE"].unique()
# Out:
# array(['B'], dtype=object)

# %%
del e_cars["Unnamed: 5"]

# %%
del e_cars["TYPE"]

# %%
e_cars
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 11  2014   CHEVROLET                         SPARK EV             SUBCOMPACT
# 12  2014        FORD                   FOCUS ELECTRIC                COMPACT
# 13  2014  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 14  2014      NISSAN                             LEAF               MID-SIZE
# 15  2014       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 16  2014       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 17  2014       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 18  2014       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 19  2014       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# 20  2015         BMW                               i3             SUBCOMPACT
# 21  2015   CHEVROLET                         SPARK EV             SUBCOMPACT
# 22  2015        FORD                   FOCUS ELECTRIC                COMPACT
# 23  2015         KIA                          SOUL EV  STATION WAGON - SMALL
# 24  2015  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 25  2015      NISSAN                             LEAF               MID-SIZE
# 26  2015       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 27  2015       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 28  2015       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 29  2015       TESLA         MODEL S (70 kWh battery)              FULL-SIZE
# 30  2015       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 31  2015       TESLA                      MODEL S 70D              FULL-SIZE
# 32  2015       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 33  2015       TESLA                MODEL S P85D/P90D              FULL-SIZE
# 34  2016         BMW                               i3             SUBCOMPACT
# 35  2016   CHEVROLET                         SPARK EV             SUBCOMPACT
# 36  2016        FORD                   FOCUS ELECTRIC                COMPACT
# 37  2016         KIA                          SOUL EV  STATION WAGON - SMALL
# 38  2016  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 39  2016      NISSAN            LEAF (24 kWh battery)               MID-SIZE
# 40  2016      NISSAN            LEAF (30 kWh battery)               MID-SIZE
# 41  2016       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 42  2016       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 43  2016       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 44  2016       TESLA         MODEL S (70 kWh battery)              FULL-SIZE
# 45  2016       TESLA      MODEL S (85/90 kWh battery)              FULL-SIZE
# 46  2016       TESLA                      MODEL S 70D              FULL-SIZE
# 47  2016       TESLA                  MODEL S 85D/90D              FULL-SIZE
# 48  2016       TESLA            MODEL S 90D (Refresh)              FULL-SIZE
# 49  2016       TESLA                MODEL S P85D/P90D              FULL-SIZE
# 50  2016       TESLA           MODEL S P90D (Refresh)              FULL-SIZE
# 51  2016       TESLA                      MODEL X 90D         SUV - STANDARD
# 52  2016       TESLA                     MODEL X P90D         SUV - STANDARD
#
#     (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 0     49               16.9              21.4               18.7
# 1     80               19.3              23.0               21.1
# 2    107               19.0              21.1               20.0
# 3     49               16.9              21.4               18.7
# 4     80               19.3              23.0               21.1
# 5     35               17.2              22.5               19.6
# 6     35               17.2              22.5               19.6
# 7    270               22.4              21.9               22.2
# 8    270               22.2              21.7               21.9
# 9    270               23.8              23.2               23.6
# 10   310               23.9              23.2               23.6
# 11   104               16.0              19.6               17.8
# 12   107               19.0              21.1               20.0
# 13    49               16.9              21.4               18.7
# 14    80               16.5              20.8               18.4
# 15    35               17.2              22.5               19.6
# 16    35               17.2              22.5               19.6
# 17   225               22.2              21.7               21.9
# 18   270               23.8              23.2               23.6
# 19   310               23.9              23.2               23.6
# 20   125               15.2              18.8               16.8
# 21   104               16.0              19.6               17.8
# 22   107               19.0              21.1               20.0
# 23    81               17.5              22.7               19.9
# 24    49               16.9              21.4               18.7
# 25    80               16.5              20.8               18.4
# 26    35               17.2              22.5               19.6
# 27    35               17.2              22.5               19.6
# 28   283               22.2              21.7               21.9
# 29   283               23.8              23.2               23.6
# 30   283               23.8              23.2               23.6
# 31   280               20.8              20.6               20.7
# 32   280               22.0              19.8               21.0
# 33   515               23.4              21.5               22.5
# 34   125               15.2              18.8               16.8
# 35   104               16.0              19.6               17.8
# 36   107               19.0              21.1               20.0
# 37    81               17.5              22.7               19.9
# 38    49               16.9              21.4               18.7
# 39    80               16.5              20.8               18.4
# 40    80               17.0              20.7               18.6
# 41    35               17.2              22.5               19.6
# 42    35               17.2              22.5               19.6
# 43   283               22.2              21.7               21.9
# 44   283               23.8              23.2               23.6
# 45   283               23.8              23.2               23.6
# 46   386               20.8              20.6               20.7
# 47   386               22.0              19.8               21.0
# 48   386               20.8              19.7               20.3
# 49   568               23.4              21.5               22.5
# 50   568               22.9              21.0               22.1
# 51   386               23.2              22.2               22.7
# 52   568               23.6              23.3               23.5
#
#     CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  \
# 0                1.9              2.4               2.1       0     NaN   100
# 1                2.2              2.6               2.4       0     NaN   117
# 2                2.1              2.4               2.2       0     NaN   122
# 3                1.9              2.4               2.1       0     NaN   100
# 4                2.2              2.6               2.4       0     NaN   117
# 5                1.9              2.5               2.2       0     NaN   109
# 6                1.9              2.5               2.2       0     NaN   109
# 7                2.5              2.5               2.5       0     NaN   224
# 8                2.5              2.4               2.5       0     NaN   335
# 9                2.7              2.6               2.6       0     NaN   426
# 10               2.7              2.6               2.6       0     NaN   426
# 11               1.8              2.2               2.0       0     NaN   131
# 12               2.1              2.4               2.2       0     NaN   122
# 13               1.9              2.4               2.1       0     NaN   100
# 14               1.9              2.3               2.1       0     NaN   135
# 15               1.9              2.5               2.2       0     NaN   109
# 16               1.9              2.5               2.2       0     NaN   109
# 17               2.5              2.4               2.5       0     NaN   335
# 18               2.7              2.6               2.6       0     NaN   426
# 19               2.7              2.6               2.6       0     NaN   426
# 20               1.7              2.1               1.9       0     NaN   130
# 21               1.8              2.2               2.0       0     NaN   131
# 22               2.1              2.4               2.2       0     NaN   122
# 23               2.0              2.6               2.2       0     NaN   149
# 24               1.9              2.4               2.1       0     NaN   100
# 25               1.9              2.3               2.1       0     NaN   135
# 26               1.9              2.5               2.2       0     NaN   109
# 27               1.9              2.5               2.2       0     NaN   109
# 28               2.5              2.4               2.5       0     NaN   335
# 29               2.7              2.6               2.6       0     NaN   377
# 30               2.7              2.6               2.6       0     NaN   426
# 31               2.3              2.3               2.3       0     NaN   386
# 32               2.5              2.2               2.4       0     NaN   435
# 33               2.6              2.4               2.5       0     NaN   407
# 34               1.7              2.1               1.9       0    10.0   130
# 35               1.8              2.2               2.0       0    10.0   131
# 36               2.1              2.4               2.2       0    10.0   122
# 37               2.0              2.6               2.2       0    10.0   149
# 38               1.9              2.4               2.1       0    10.0   100
# 39               1.9              2.3               2.1       0    10.0   135
# 40               1.9              2.3               2.1       0    10.0   172
# 41               1.9              2.5               2.2       0    10.0   109
# 42               1.9              2.5               2.2       0    10.0   109
# 43               2.5              2.4               2.5       0    10.0   335
# 44               2.7              2.6               2.6       0    10.0   377
# 45               2.7              2.6               2.6       0    10.0   426
# 46               2.3              2.3               2.3       0    10.0   386
# 47               2.5              2.2               2.4       0    10.0   435
# 48               2.3              2.2               2.3       0    10.0   473
# 49               2.6              2.4               2.5       0    10.0   407
# 50               2.6              2.4               2.5       0    10.0   435
# 51               2.6              2.5               2.6       0    10.0   414
# 52               2.7              2.6               2.6       0    10.0   402
#
#     TIME (h)
# 0          7
# 1          7
# 2          4
# 3          7
# 4          7
# 5          8
# 6          8
# 7          6
# 8         10
# 9         12
# 10        12
# 11         7
# 12         4
# 13         7
# 14         5
# 15         8
# 16         8
# 17        10
# 18        12
# 19        12
# 20         4
# 21         7
# 22         4
# 23         4
# 24         7
# 25         5
# 26         8
# 27         8
# 28        10
# 29        12
# 30        12
# 31        12
# 32        12
# 33        12
# 34         4
# 35         7
# 36         4
# 37         4
# 38         7
# 39         5
# 40         6
# 41         8
# 42         8
# 43        10
# 44        12
# 45        12
# 46        12
# 47        12
# 48        12
# 49        12
# 50        12
# 51        12
# 52        12

# %%
e_cars.dtypes
# Out:
# YEAR                   int64
# Make                  object
# Model                 object
# Size                  object
# (kW)                   int64
# CITY (kWh/100 km)    float64
# HWY (kWh/100 km)     float64
# COMB (kWh/100 km)    float64
# CITY (Le/100 km)     float64
# HWY (Le/100 km)      float64
# COMB (Le/100 km)     float64
# (g/km)                 int64
# RATING               float64
# (km)                   int64
# TIME (h)               int64
# dtype: object

# %%
e_cars["Size"].value_counts()
# Out:
# FULL-SIZE                21
# SUBCOMPACT               10
# TWO-SEATER                8
# MID-SIZE                  6
# COMPACT                   4
# STATION WAGON - SMALL     2
# SUV - STANDARD            2
# Name: Size, dtype: int64

# %% [markdown]
# Obzirom da su podaci u prilično dobrom stanju, ovdje možemo reći da nemamo previše posla oko čišćenja podataka, a analizu ćemo ostaviti za neki drugi put.

# %% [markdown]
# ## Zadatak
#
# Učitati podatke iz datoteke `titanic_data.csv` u `dataframe` i odraditi njihovu normalizaciju, tj čišćenje.

# %%
titanic_data = pd.read_csv("podaci/titanic_data.csv")

titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data = titanic_data.rename(columns={"Pclass": "Passenger class"})

# %%
titanic_data.rename(
    columns={
        "Passenger class": "Passenger Class",
        "SibSp": "Siblings/Spouses Aboard",
        "Parch": "Parents/Children Aboard",
        "Fare": "Fare (£)",
        "Embarked": "Port of Entry"
    },
    inplace=True
)

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Passenger Class', 'Name', 'Sex', 'Age',
#        'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Ticket',
#        'Fare (£)', 'Cabin', 'Port of Entry'],
#       dtype='object')

# %%
titanic_data_copy = titanic_data.copy()

# %%
titanic_data_copy.columns = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J", "K", "L"]

# %%
titanic_data_copy
# Out:
#        A  B  C                                                  D       E  \
# 0      1  0  3                            Braund, Mr. Owen Harris    male
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      3  1  3                             Heikkinen, Miss. Laina  female
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      5  0  3                           Allen, Mr. William Henry    male
# ..   ... .. ..                                                ...     ...
# 886  887  0  2                              Montvila, Rev. Juozas    male
# 887  888  1  1                       Graham, Miss. Margaret Edith  female
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889  890  1  1                              Behr, Mr. Karl Howell    male
# 890  891  0  3                                Dooley, Mr. Patrick    male
#
#         F  G  H                 I        J     K  L
# 0    22.0  1  0         A/5 21171   7.2500   NaN  S
# 1    38.0  1  0          PC 17599  71.2833   C85  C
# 2    26.0  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3    35.0  1  0            113803  53.1000  C123  S
# 4    35.0  0  0            373450   8.0500   NaN  S
# ..    ... .. ..               ...      ...   ... ..
# 886  27.0  0  0            211536  13.0000   NaN  S
# 887  19.0  0  0            112053  30.0000   B42  S
# 888   NaN  1  2        W./C. 6607  23.4500   NaN  S
# 889  26.0  0  0            111369  30.0000  C148  C
# 890  32.0  0  0            370376   7.7500   NaN  Q
#
# [891 rows x 12 columns]

# %%
titanic_data
# Out:
#      PassengerId  Survived  Passenger Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard            Ticket  \
# 0                          1                        0         A/5 21171
# 1                          1                        0          PC 17599
# 2                          0                        0  STON/O2. 3101282
# 3                          1                        0            113803
# 4                          0                        0            373450
# ..                       ...                      ...               ...
# 886                        0                        0            211536
# 887                        0                        0            112053
# 888                        1                        2        W./C. 6607
# 889                        0                        0            111369
# 890                        0                        0            370376
#
#      Fare (£) Cabin Port of Entry
# 0      7.2500   NaN             S
# 1     71.2833   C85             C
# 2      7.9250   NaN             S
# 3     53.1000  C123             S
# 4      8.0500   NaN             S
# ..        ...   ...           ...
# 886   13.0000   NaN             S
# 887   30.0000   B42             S
# 888   23.4500   NaN             S
# 889   30.0000  C148             C
# 890    7.7500   NaN             Q
#
# [891 rows x 12 columns]

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PassengerId              891 non-null    int64
#  1   Survived                 891 non-null    int64
#  2   Passenger Class          891 non-null    int64
#  3   Name                     891 non-null    object
#  4   Sex                      891 non-null    object
#  5   Age                      714 non-null    float64
#  6   Siblings/Spouses Aboard  891 non-null    int64
#  7   Parents/Children Aboard  891 non-null    int64
#  8   Ticket                   891 non-null    object
#  9   Fare (£)                 891 non-null    float64
#  10  Cabin                    204 non-null    object
#  11  Port of Entry            889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data["Port of Entry"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# Obzirom da `Port of Entry` podaci nemaju prevelikog smisla, idemo ih promijeniti na sljedeći način:
# - ako je vrijednost `S`, promijeniti je u `Southampton`
# - ako je vrijednost `C`, promijeniti je u `Cherbourg`
# - ako je vrijednost `Q`, promijeniti je u `Queenstown`
#
# Prazne vrijednosti ostaviti kakve jesu.

# %%
titanic_data.loc[titanic_data["Port of Entry"] == "S", "Port of Entry"] = "Southampon"

# %%
titanic_data
# Out:
#      PassengerId  Survived  Passenger Class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard            Ticket  \
# 0                          1                        0         A/5 21171
# 1                          1                        0          PC 17599
# 2                          0                        0  STON/O2. 3101282
# 3                          1                        0            113803
# 4                          0                        0            373450
# ..                       ...                      ...               ...
# 886                        0                        0            211536
# 887                        0                        0            112053
# 888                        1                        2        W./C. 6607
# 889                        0                        0            111369
# 890                        0                        0            370376
#
#      Fare (£) Cabin Port of Entry
# 0      7.2500   NaN    Southampon
# 1     71.2833   C85             C
# 2      7.9250   NaN    Southampon
# 3     53.1000  C123    Southampon
# 4      8.0500   NaN    Southampon
# ..        ...   ...           ...
# 886   13.0000   NaN    Southampon
# 887   30.0000   B42    Southampon
# 888   23.4500   NaN    Southampon
# 889   30.0000  C148             C
# 890    7.7500   NaN             Q
#
# [891 rows x 12 columns]

# %%
titanic_data_copy
# Out:
#        A            B            C  \
# 0    bla  Southampton  Southampton
# 1    bla            1            1
# 2    bla  Southampton  Southampton
# 3    bla  Southampton  Southampton
# 4    bla  Southampton  Southampton
# ..   ...          ...          ...
# 886  bla  Southampton  Southampton
# 887  bla  Southampton  Southampton
# 888  bla  Southampton  Southampton
# 889  bla            1            1
# 890  bla            0            3
#
#                                                      D            E  \
# 0                                          Southampton  Southampton
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       female
# 2                                          Southampton  Southampton
# 3                                          Southampton  Southampton
# 4                                          Southampton  Southampton
# ..                                                 ...          ...
# 886                                        Southampton  Southampton
# 887                                        Southampton  Southampton
# 888                                        Southampton  Southampton
# 889                              Behr, Mr. Karl Howell         male
# 890                                Dooley, Mr. Patrick         male
#
#                F            G            H            I            J  \
# 0    Southampton  Southampton  Southampton  Southampton  Southampton
# 1           38.0            1            0     PC 17599      71.2833
# 2    Southampton  Southampton  Southampton  Southampton  Southampton
# 3    Southampton  Southampton  Southampton  Southampton  Southampton
# 4    Southampton  Southampton  Southampton  Southampton  Southampton
# ..           ...          ...          ...          ...          ...
# 886  Southampton  Southampton  Southampton  Southampton  Southampton
# 887  Southampton  Southampton  Southampton  Southampton  Southampton
# 888  Southampton  Southampton  Southampton  Southampton  Southampton
# 889         26.0            0            0       111369         30.0
# 890         32.0            0            0       370376         7.75
#
#                K            L
# 0    Southampton  Southampton
# 1            C85            C
# 2    Southampton  Southampton
# 3    Southampton  Southampton
# 4    Southampton  Southampton
# ..           ...          ...
# 886  Southampton  Southampton
# 887  Southampton  Southampton
# 888  Southampton  Southampton
# 889         C148            C
# 890          NaN            Q
#
# [891 rows x 12 columns]
