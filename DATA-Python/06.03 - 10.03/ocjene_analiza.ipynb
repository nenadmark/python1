# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
grades_df = pd.read_csv("podaci/ocjene.csv")

# %%
grades_df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %% [markdown]
# ## ZADATAK 1

# %% [markdown]
# 1. ispisati broj redaka u dataframeu
# 2. provjeriti tipove podataka u dataframe-u i odraditi prilagodbu ukoliko je potrebno
# 3. preimenovati stupce u proizvoljne (ali smislene) nazive u hrv jeziku
# 4. izdvojiti podatke u dva odvojena dataframea, po jedan za svaki spol
# 5. svaki od 2 nova dataframea-sortirati po dobi
# 6. za originalni dataframe ispisati sljedece vrijednosti:
#     - prosjek ocjena
#     - minimalna i maksimalna ocjena
# 7. statisticke podatke iz prethodnog zadatka izvuci posebno ua svaki spol

# %%
#1
grades_df.info()

print(f"dataframe se sastoji od {len(grades_df)} redaka.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fname     2000 non-null   object
#  1   lname     2000 non-null   object
#  2   gender    2000 non-null   object
#  3   age       2000 non-null   int64
#  4   exercise  2000 non-null   int64
#  5   hours     2000 non-null   int64
#  6   grade     2000 non-null   float64
#  7   address   2000 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 125.1+ KB
# dataframe se sastoji od 2000 redaka.

# %%
#2
grades_df.dtypes
# Out:
# fname        object
# lname        object
# gender       object
# age           int64
# exercise      int64
# hours         int64
# grade       float64
# address      object
# dtype: object

# %%
#3
grades_df.rename(columns = {'fname':'Ime', 'lname':'Prezime',
                              'gender':'spol', 'age':'Dob', 
                            'exercise':'Vježba', 'hours':'Broj sati', 
                            'grade':'Ocjena', 'address':'Adresa'}, inplace = True)

# %%
#4
ocjene_muski_df = ocjene_df[ocjene_df['spol'] == "male"]
# ocjene_muski_df = grades_df.query('spol = "male"')
ocjene_zenski_df = ocjene_df[ocjene_df['spol'] == "female"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #4
# ----> 2 ocjene_muski_df = ocjene_df[ocjene_df['spol'] == "male"]
#       3 # ocjene_muski_df = grades_df.query('spol = "male"')
#       4 ocjene_zenski_df = ocjene_df[ocjene_df['spol'] == "female"]
#
# NameError: name 'ocjene_df' is not defined

# %%
#5
ocjene_muski_df.sort_values(by=['Dob'])
ocjene_zenski_df.sort_values(by=['Dob'])
ocjene_zenski_df = ocjene_zenski_df.reset_index(drop=True, inplace=True)
ocjene_zenski_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #5
# ----> 2 ocjene_muski_df.sort_values(by=['Dob'])
#       3 ocjene_zenski_df.sort_values(by=['Dob'])
#       4 ocjene_zenski_df = ocjene_zenski_df.reset_index(drop=True, inplace=True)
#
# NameError: name 'ocjene_muski_df' is not defined

# %%
#6
grades_df
# Out:
#             Ime   Prezime    spol  Dob  Vježba  Broj sati  Ocjena  \
# 0        Marcia      Pugh  female   17       3         10    82.4
# 1        Kadeem  Morrison    male   18       4          4    78.2
# 2          Nash    Powell    male   18       5          9    79.3
# 3       Noelani    Wagner  female   14       2          7    83.2
# 4       Noelani    Cherry  female   18       4         15    87.4
# ...         ...       ...     ...  ...     ...        ...     ...
# 1995       Cody  Shepherd    male   19       1          8    80.1
# 1996  Geraldine  Peterson  female   16       4         18   100.0
# 1997   Mercedes      Leon  female   18       3         14    84.9
# 1998     Lucius   Rowland    male   16       1          7    69.1
# 1999      Linus    Morris    male   19       4         10    79.6
#
#                                            Adresa
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# ...

# %%
#8
grades_df[["Ulica", "Grad", "Drzava"]] = grades_df["Adresa"].str.split(", ", expand=True)

# %%
grades_df
# Out:
#             Ime   Prezime    spol  Dob  Vježba  Broj sati  Ocjena  \
# 0        Marcia      Pugh  female   17       3         10    82.4
# 1        Kadeem  Morrison    male   18       4          4    78.2
# 2          Nash    Powell    male   18       5          9    79.3
# 3       Noelani    Wagner  female   14       2          7    83.2
# 4       Noelani    Cherry  female   18       4         15    87.4
# ...         ...       ...     ...  ...     ...        ...     ...
# 1995       Cody  Shepherd    male   19       1          8    80.1
# 1996  Geraldine  Peterson  female   16       4         18   100.0
# 1997   Mercedes      Leon  female   18       3         14    84.9
# 1998     Lucius   Rowland    male   16       1          7    69.1
# 1999      Linus    Morris    male   19       4         10    79.6
#
#                                            Adresa                      Ulica  \
# 0         9253 Richardson Road, Matawan, NJ 07747       9253 Richardson Road
# ...

# %%
grades_df["Ocjena"].plot.hist(bins=10)
plt.xlabel("Ocjena")
plt.ylabel("Broj ucenika")
plt.title("histogram")
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
grades_df.plot(kind="box", x="spol", y="Ocjena")
# Out:
# <Axes: >

# %%
grades_df.describe() # ispisuje median vrijednosti svih stupaca
# Out:
#                Dob       Vježba    Broj sati       Ocjena
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean     16.578500     3.000500    10.988500    82.556050
# std       1.696254     1.423205     4.063942     9.747593
# min      14.000000     0.000000     0.000000    32.000000
# 25%      15.000000     2.000000     8.000000    75.575000
# 50%      17.000000     3.000000    11.000000    82.700000
# 75%      18.000000     4.000000    14.000000    89.700000
# max      19.000000     5.000000    20.000000   100.000000

# %%
grades_df.boxplot(column="Ocjena", by="spol") 
# ovo bi bio dobar graficki prikaz onoga sto nam vraca describe
# Out:
# <Axes: title={'center': 'Ocjena'}, xlabel='spol'>

# %%
# prikaz korelacije dva stupca (pandas prikaz bez grafike)
# brzi pregled
grades_df.corr()
# Out:
# C:\Users\hyperv\AppData\Local\Temp\ipykernel_8256\2911491610.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   grades_df.corr()
#                 Dob    Vježba  Broj sati    Ocjena
# Dob        1.000000 -0.003643  -0.017467 -0.007580
# Vježba    -0.003643  1.000000   0.021105  0.161286
# Broj sati -0.017467  0.021105   1.000000  0.801955
# Ocjena    -0.007580  0.161286   0.801955  1.000000

# %%
grades_df.plot.scatter(x="Broj sati", y="Ocjena")
# Out:
# <Axes: xlabel='Broj sati', ylabel='Ocjena'>

# %%
# prikaz korelacije dva stupca ( graficki prikaz uz pomoc seaborn-a)

sns.heatmap(data=grades_df.corr(), annot=True, vmin=-1, vmax=1)
# Out:
# C:\Users\hyperv\AppData\Local\Temp\ipykernel_8256\2834822858.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=grades_df.corr(), annot=True, vmin=-1, vmax=1)
# <Axes: >

# %% [markdown]
# ## Zadatak:
# - prikazati na "bar" grafu prosjecne ocjene po spolu.

# %%
grades_df.groupby("spol")["Ocjena"].mean().plot.bar()
#grades_df.plot.bar(x="Ocjena", y="spol")
# Out:
# <Axes: xlabel='spol'>

# %% [markdown]
# ## Zadatak
# - prikazati na "bar" grafu prosjek ocjena o po saveznim drzavama

# %%
plt.rcParams['figure.figsize'] = [10, 8]
grades_df.groupby("Grad")["Ocjena"].mean().plot.barh()
# Out:
# <Axes: ylabel='Grad'>

# %%
grades_df.groupby("Grad")["Ocjena"].mean().sort_values(ascending=False).head(5).plot.barh()
# Out:
# <Axes: ylabel='Grad'>

# %%
grades_df.groupby("Grad")["Ocjena"].mean().head(60).plot.barh()
# Out:
# <Axes: ylabel='Grad'>

# %% [markdown]
# ### prikazati prosjek ocjena po spolu grupiran ( prosjek, min, max)

# %%
grades_df.groupby("spol")["Ocjena"].mean().sort_values(ascending=False).head(5).plot.barh()
# Out:
# <Axes: ylabel='spol'>

# %%
mean1 = grades_df["Ocjena"].mean()
min1 = grades_df["Ocjena"].min()
max1 = grades_df["Ocjena"].max()

# %%
grades_df.groupby("spol")["mean1", "min1", "max1"].sort_values(ascending=False).plot.barh()
# Out:
# C:\Users\hyperv\AppData\Local\Temp\ipykernel_8256\3031280089.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grades_df.groupby("spol")["mean1", "min1", "max1"].sort_values(ascending=False).plot.barh()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 grades_df.groupby("spol")["mean1", "min1", "max1"].sort_values(ascending=False).plot.barh()
#
# File c:\programdata\miniconda3\lib\site-packages\pandas\core\groupby\generic.py:1416, in DataFrameGroupBy.__getitem__(self, key)
#    1407 if isinstance(key, tuple) and len(key) > 1:
#    1408     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1409     # valid syntax, so don't raise warning
#    1410     warnings.warn(
# ...
