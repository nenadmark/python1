# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - My analysis in which country would be the best to live in if you are a young person up to 27 years old.
#
# - The selected country would be Norway.

# %% [markdown]
# # The following is an analysis of certain datasets:

# %% [markdown]
# ## 1. - Happiness score (WHR)
#
# - This is the national average response to the question of life evaluations asking the following: “Please imagine a ladder, with steps numbered from 0 at the bottom to 10 at the top. The top of the ladder represents the best possible life for you and the bottom of the ladder represents the worst possible life for you.
# - This measure is also referred to as Cantril life ladder.
# - Gapminder has converted this indicator's scale from 0 to 100 to easly communicate it in terms of percentage.
#
#
# - Norway: 7. place

# %%
df_happiness = pd.read_csv("hapiscore_whr.csv")
df_happiness.set_index("country", inplace = True)
df_happiness.head()
# Out:
#                       2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# country
# Afghanistan            NaN   NaN   NaN  37.2  44.0  47.6  38.3  37.8  35.7
# Angola                 NaN   NaN   NaN   NaN   NaN   NaN  55.9  43.6  39.4
# Albania                NaN   NaN  46.3   NaN  54.9  52.7  58.7  55.1  45.5
# United Arab Emirates   NaN  67.3   NaN   NaN  68.7  71.0  71.2  72.2  66.2
# Argentina              NaN  63.1  60.7  59.6  64.2  64.4  67.8  64.7  65.8
#
#                       2014  2015  2016  2017  2018  2019  2020  2021  2022
# country
# Afghanistan           31.3  39.8  42.2  26.6  26.9  23.8   NaN  24.4  18.6
# Angola                38.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania               48.1  46.1  45.1  46.4  50.0  50.0  53.6  52.5  52.8
# United Arab Emirates  65.4  65.7  68.3  70.4  66.0  67.1  64.6  67.3  65.7
# Argentina             66.7  67.0  64.3  60.4  57.9  60.9  59.0  59.1  60.2

# %%
top10by_happiness = df_happiness["2022"].sort_values(ascending=False).head(10)
top10by_happiness
# Out:
# country
# Finland        78.0
# Denmark        75.9
# Iceland        75.3
# Israel         74.7
# Netherlands    74.0
# Sweden         74.0
# Norway         73.2
# Switzerland    72.4
# Luxembourg     72.3
# New Zealand    71.2
# Name: 2022, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_happiness.index, top10by_happiness)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 2. - Life expectancy
#
# - The average number of years a newborn child would live if current mortality patterns were to stay the same.
#
# - Norway: 10. place

# %%
df_life_expectancy = pd.read_csv("life_expectancy_years.csv")
df_life_expectancy.set_index("country", inplace = True)
df_life_expectancy.head()
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Afghanistan           28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1
# Angola                27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# Albania               35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# Andorra                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
#
#                       1809  ...  2091  2092  2093  2094  2095  2096  2097  \
# country                     ...
# Afghanistan           28.1  ...  75.5  75.7  75.8  76.0  76.1  76.2  76.4
# Angola                27.0  ...  78.8  79.0  79.1  79.2  79.3  79.5  79.6
# Albania               35.4  ...  87.4  87.5  87.6  87.7  87.8  87.9  88.0
# Andorra                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United Arab Emirates  30.7  ...  82.4  82.5  82.6  82.7  82.8  82.9  83.0
#
# ...

# %%
top10by_life_expectancy = df_life_expectancy["2022"].sort_values(ascending=False).head(10)
top10by_life_expectancy
# Out:
# country
# Singapore           85.3
# Japan               85.2
# Hong Kong, China    84.8
# Iceland             84.5
# Switzerland         84.4
# Spain               83.5
# Israel              83.5
# Italy               83.5
# Luxembourg          83.4
# Norway              83.4
# Name: 2022, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_life_expectancy.index, top10by_life_expectancy)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 3. - Number of people using internet
#
# - Total number of people who used internet in the last 3 months.
# - This is calculated by multiplying the share of internet users with population.
#
# - Norway: 10. place

# %%
df_net_users_num = pd.read_csv("net_users_num.csv")
df_net_users_num.set_index("country", inplace = True)
df_net_users_num.head()
# Out:
#                      1990 1991 1992 1993 1994  1995  1996  1997  1998   1999  \
# country
# Afghanistan             0    0    0    0    0     0   NaN   NaN   NaN    NaN
# Angola                  0    0    0    0    0     0   112   844  2830  11.4k
# Albania                 0    0    0    0    0   348   998  1510  2020   2540
# Andorra                 0    0    0    0    0     0   983  1960  4420   4920
# United Arab Emirates    0    0    0    0    0  2490  9530   88k  194k   443k
#
#                       ...   2010   2011   2012   2013   2014   2015   2016  \
# country               ...
# Afghanistan           ...  1.17M  1.51M   1.7M   1.9M  2.34M  2.84M  3.96M
# Angola                ...   654k   751k  1.63M  2.32M  5.77M  3.46M  3.75M
# Albania               ...  1.33M  1.44M  1.59M  1.66M  1.74M  1.83M  1.92M
# Andorra               ...  68.4k  67.8k  71.2k  75.9k    76k  75.6k  75.7k
# United Arab Emirates  ...  5.81M  6.98M  7.77M  8.09M  8.33M  8.38M  8.48M
#
# ...

# %%
top10by_net_users = df_life_expectancy["2022"].sort_values(ascending=False).head(10)
top10by_net_users
# Out:
# country
# Singapore           85.3
# Japan               85.2
# Hong Kong, China    84.8
# Iceland             84.5
# Switzerland         84.4
# Spain               83.5
# Israel              83.5
# Italy               83.5
# Luxembourg          83.4
# Norway              83.4
# Name: 2022, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_net_users.index, top10by_net_users)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 4. - Corruption Perception Index (pre 2012 method)
#
# - Transparency International's score of perceptions of corruption.
# - Higher values indicate less corruption.
# - Norway: 6. place

# %%
df_corruption_perception_index = pd.read_csv("corruption_perception_index_cpi_pre2012.csv")
df_corruption_perception_index.set_index("country", inplace = True)
df_corruption_perception_index.head()
# Out:
#                       1995  1996  1997  1998  1999  2000  2001  2002  2003  \
# country
# Afghanistan            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                 NaN   NaN   NaN   NaN   NaN   1.7   NaN   1.7   1.8
# Albania                NaN   NaN   NaN   NaN   2.3   NaN   NaN   2.5   2.5
# United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.2
# Argentina             5.24  3.41  2.81   3.0   3.0   3.5   3.5   2.8   2.5
#
#                       2004  2005  2006  2007  2008  2009  2010  2011
# country
# Afghanistan            NaN   2.5   NaN   1.8   1.5   1.3   1.4  1.52
# Angola                 2.0   2.0   2.2   2.2   1.9   1.9   1.9  2.01
# Albania                2.5   2.4   2.6   2.9   3.4   3.2   3.3  3.05
# United Arab Emirates   6.1   6.2   6.2   5.7   5.9   6.5   6.3  6.82
# Argentina              2.5   2.8   2.9   2.9   2.9   2.9   2.9  3.00

# %%
top10by_corruption_perception_index = df_corruption_perception_index["2011"].sort_values(ascending=False).head(10)
top10by_corruption_perception_index
# Out:
# country
# New Zealand    9.46
# Finland        9.40
# Denmark        9.39
# Sweden         9.30
# Singapore      9.17
# Norway         8.99
# Netherlands    8.89
# Australia      8.84
# Switzerland    8.80
# Canada         8.67
# Name: 2011, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_corruption_perception_index.index, top10by_corruption_perception_index)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 5. - Average hourly labour cost per employee
#
# - Average hourly labour cost per employee (in USD)
# - Norway: 2. place

# %%
df_hourly_labour = pd.read_csv("hourly_labour_cost_constant_2017_usd.csv")
df_hourly_labour.set_index("country", inplace = True)
df_hourly_labour.head()
# Out:
#             1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  ...  \
# country                                                                 ...
# Argentina    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Armenia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Australia   12.9   NaN   NaN  14.3   NaN   NaN   NaN   NaN   NaN  16.4  ...
# Austria      NaN   NaN   NaN   NaN   NaN   NaN  25.4  25.5  26.4  27.6  ...
# Azerbaijan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#              2011   2012   2013   2014   2015   2016   2017   2018  2019  2020
# country
# Argentina    0.92   1.04    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# Armenia      4.23   4.59   6.12   6.07   6.62   7.07   7.52   8.22   NaN   NaN
# Australia   20.10    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# Austria     33.80  34.70    NaN    NaN    NaN  39.10  39.30  40.70  41.3  43.5
# ...

# %%
top10by_hourly_labour = df_hourly_labour["2020"].sort_values(ascending=False).head(10)
top10by_hourly_labour
# Out:
# country
# Belgium        48.7
# Norway         47.7
# Germany        46.2
# France         44.9
# Denmark        44.5
# Austria        43.5
# Netherlands    43.1
# Luxembourg     42.3
# Sweden         40.9
# Italy          40.2
# Name: 2020, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_hourly_labour.index, top10by_hourly_labour)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 6. - Total health spending per person
#
# - The average health expenditure per person, expressed in US dollars using the average exchange rate.
# - Norway: 3. place

# %%
df_health_spending = pd.read_csv("total_health_spending_per_person_us.csv")
df_health_spending.set_index("country", inplace = True)
df_health_spending.head()
# Out:
#                         1995    1996    1997    1998     1999    2000    2001  \
# country
# Afghanistan              NaN     NaN     NaN     NaN      NaN     NaN     NaN
# Angola                  15.6    11.3    13.5     9.1     8.82    15.8    21.4
# Albania                 27.9    43.0    36.1    47.1    65.00    75.2    79.9
# Andorra               1390.0  1510.0  1460.0  1860.0  1430.00  1330.0  1290.0
# United Arab Emirates   738.0   731.0   751.0   839.0   847.00   885.0   815.0
#
#                         2002    2003    2004    2005    2006    2007    2008  \
# country
# Afghanistan             14.8    18.3    20.7    21.9    23.8    28.8    31.8
# Angola                  18.1    23.9    25.9    36.4    64.1    85.3   149.0
# Albania                 90.3   113.0   161.0   178.0   192.0   232.0   275.0
# Andorra               1490.0  1890.0  2190.0  2360.0  2630.0  3010.0  3390.0
# United Arab Emirates   917.0   968.0   995.0  1030.0  1110.0  1200.0  1530.0
#
# ...

# %%
top10by_health_spending = df_health_spending["2010"].sort_values(ascending=False).head(10)
top10by_health_spending
# Out:
# country
# United States    8360.0
# Luxembourg       8180.0
# Norway           8090.0
# Switzerland      7810.0
# Denmark          6420.0
# Monaco           6330.0
# Netherlands      5590.0
# Canada           5220.0
# Austria          4960.0
# Australia        4780.0
# Name: 2010, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_health_spending.index, top10by_health_spending)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## 7. - Murders per 100,000 people
#
# - Mortality due to interpersonal violence, per 100,000 standard population, age adjusted.
# - This rate is calculated as if all countries had the same age composition of the population.
# - Higher values indicate more mortality.
# - Norway: 6. place

# %%
df_murders = pd.read_csv("murder_per_100000_people.csv")
df_murders.set_index("country", inplace = True)
df_murders.head()
# Out:
#                      1950  1951  1952  1953  1954  1955  1956  1957  1958  \
# country
# Albania               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Argentina             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Australia             1.0  1.33  1.46  1.25   1.3  1.39   1.3  1.34  1.54
#
#                      1959  ...   2007  2008  2009  2010  2011  2012  2013  \
# country                    ...
# Albania               NaN  ...  3.070  2.96   NaN  2.30   NaN   NaN   NaN
# Argentina             NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia               NaN  ...    NaN  1.69   NaN   NaN   NaN  1.51  1.10
# Antigua and Barbuda   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Australia            1.52  ...  0.978  1.09  1.17  1.01  1.05  1.23  1.06
#
# ...

# %%
top10by_murders = df_murders["2015"].sort_values(ascending=True).head(10)
top10by_murders
# Out:
# country
# Egypt               0.166
# United Kingdom      0.192
# Japan               0.208
# Hong Kong, China    0.272
# Singapore           0.361
# Norway              0.389
# Germany             0.506
# Austria             0.508
# Spain               0.557
# Slovenia            0.560
# Name: 2015, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
ax.bar(top10by_murders.index, top10by_murders)
# Out:
# <BarContainer object of 10 artists>
